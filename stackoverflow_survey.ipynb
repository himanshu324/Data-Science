# %%
import pandas as pd

# %%
content = pd.read_csv("survey_results_public.csv")

# %%
pd.set_option('display.max_columns',61)

# %%
content
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.set_option('display.max_rows',61)
schema_df = pd.read_csv("survey_results_schema.csv")
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
schema_df['Column']
# Out:
# 0                       Respondent
# 1                       MainBranch
# 2                         Hobbyist
# 3                              Age
# 4                       Age1stCode
# 5                         CompFreq
# 6                        CompTotal
# 7                    ConvertedComp
# 8                          Country
# 9                     CurrencyDesc
# 10                  CurrencySymbol
# 11          DatabaseDesireNextYear
# 12              DatabaseWorkedWith
# 13                         DevType
# 14                         EdLevel
# 15                      Employment
# 16                       Ethnicity
# 17                          Gender
# 18                      JobFactors
# 19                          JobSat
# 20                         JobSeek
# 21          LanguageDesireNextYear
# 22              LanguageWorkedWith
# 23          MiscTechDesireNextYear
# 24              MiscTechWorkedWith
# 25    NEWCollabToolsDesireNextYear
# 26        NEWCollabToolsWorkedWith
# ...

# %%
schema_df[['Column','QuestionText']]
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
schema_df.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
content['Age1stCode'].value_counts()
# Out:
# 15    5618
# 14    5514
# 16    5463
# 18    5382
# 12    5081
#       ...
# 63       1
# 72       1
# 83       1
# 76       1
# 68       1
# Name: Age1stCode, Length: 63, dtype: int64

# %%
content.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
content.index
# Out:
# RangeIndex(start=0, stop=64461, step=1)

# %%
content.loc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
content.loc[0,'YearsCode']
# Out:
# '36'

# %%
content.reset_index(inplace=True)

# %%
schema_df.set_index('Column')
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc[0]
# Out:
# Column                                                 Respondent
# QuestionText    Randomized respondent ID number (not in order ...
# Name: 0, dtype: object

# %%
schema_df.sort_index()
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %% [markdown]
# filt = (content['Hobbyist'] == 'Yes')
# content[filt]

# %%
#this is alternate to upper method

content.columns = content.columns.str.lower()
content[content['hobbyist']=='Yes']
#content
# Out:
#        index  respondent                                         mainbranch  \
# 0          0           1                     i am a developer by profession
# 2          2           3                        i code primarily as a hobby
# 3          3           4                     i am a developer by profession
# 4          4           5  i used to be a developer by profession, but no...
# 6          6           7                     i am a developer by profession
# ...      ...         ...                                                ...
# 64456  64456       64858                                                nan
# 64457  64457       64867                                                nan
# 64458  64458       64898                                                nan
# 64459  64459       64925                                                nan
# 64460  64460       65112                                                nan
#
# ...

# %%
#this is also alternate
content.loc[filt,['MainBranch','Age','Country']]
# Out:
#                                               MainBranch   Age        Country
# 7                         I am a developer by profession  36.0  United States
# 16                        I am a developer by profession  25.0  United States
# 21                        I am a developer by profession   NaN          India
# 25                        I am a developer by profession   NaN         Canada
# 26     I used to be a developer by profession, but no...   NaN  United States
# ...                                                  ...   ...            ...
# 64388                                                NaN  56.0  United States
# 64391                                                NaN   NaN          India
# 64402                                                NaN   NaN        Germany
# 64413                                                NaN  32.0  United States
# 64443                                                NaN   NaN  United States
#
# [11357 rows x 3 columns]

# %%
#~ negation is used to reverse the result to the condition
content.loc[~filt,['MainBranch','Age','Country']]
# Out:
#                                               MainBranch   Age  \
# 0                         I am a developer by profession   NaN
# 1                         I am a developer by profession   NaN
# 2                            I code primarily as a hobby   NaN
# 3                         I am a developer by profession  25.0
# 4      I used to be a developer by profession, but no...  31.0
# ...                                                  ...   ...
# 64456                                                NaN   NaN
# 64457                                                NaN   NaN
# 64458                                                NaN   NaN
# 64459                                                NaN   NaN
# 64460                                                NaN   NaN
#
#                   Country
# 0                 Germany
# 1          United Kingdom
# 2      Russian Federation
# 3                 Albania
# 4           United States
# ...                   ...
# ...

# %%
high_salary = (content['ConvertedComp']>70000)
content[high_salary]
# Out:
#        index  Respondent                                         MainBranch  \
# 7          7           8                     I am a developer by profession
# 15        15          16                     I am a developer by profession
# 16        16          17                     I am a developer by profession
# 17        17          18                     I am a developer by profession
# 18        18          19                     I am a developer by profession
# ...      ...         ...                                                ...
# 64113  64113       65586                     I am a developer by profession
# 64116  64116       65589                     I am a developer by profession
# 64127  64127       65602  I am not primarily a developer, but I write co...
# 64129  64129       65604                     I am a developer by profession
# 64141  64141       65617                     I am a developer by profession
#
# ...

# %%
countries = ['United States','Canada','India','Germany']
fil = content['Country'].isin(countries)
content.loc[fil]
# Out:
#        index  Respondent                                         MainBranch  \
# 0          0           1                     I am a developer by profession
# 4          4           5  I used to be a developer by profession, but no...
# 5          5           6                     I am a developer by profession
# 6          6           7                     I am a developer by profession
# 7          7           8                     I am a developer by profession
# ...      ...         ...                                                ...
# 64441  64441       62834                                                NaN
# 64442  64442       62954                                                NaN
# 64443  64443       63077                                                NaN
# 64452  64452       64236                                                NaN
# 64456  64456       64858                                                NaN
#
# ...

# %%
# here we have used isin() and .str.contains('str') these are especiall functions for series
filt = cond = (content['Country'].isin(['United States','Canada','Germany','India'])) & (content['LanguageWorkedWith'].str.contains('Python'))
content.loc[filt]
# Out:
#        index  Respondent                                         MainBranch  \
# 7          7           8                     I am a developer by profession
# 16        16          17                     I am a developer by profession
# 21        21          22                     I am a developer by profession
# 25        25          26                     I am a developer by profession
# 26        26          27  I used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64388  64388       54361                                                NaN
# 64391  64391       54757                                                NaN
# 64402  64402       56263                                                NaN
# 64413  64413       58498                                                NaN
# 64443  64443       63077                                                NaN
#
# ...

# %%
content.loc[filt,'LanguageWorkedWith']
# Out:
# 7                                               Python;SQL
# 16                   C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 21                                             Java;Python
# 25                                       JavaScript;Python
# 26             Bash/Shell/PowerShell;C;C++;Java;Python;SQL
#                                ...
# 64388    Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 64391            C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 64402    Assembly;C;C#;Haskell;Java;Kotlin;PHP;Python;R...
# 64413    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64443              C++;HTML/CSS;Java;JavaScript;Python;SQL
# Name: LanguageWorkedWith, Length: 11357, dtype: object

# %% [markdown]
# # this lecture'll be based on updating the row and column

# %%
#columns related queries
content.columns = [str(x).upper() for x in content.columns]
content.columns = content.columns.str.replace(' ','_')

# %%
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     i am a developer by profession
# 1          1           2                                              hello
# 2          2           3                        i code primarily as a hobby
# 3          3           4                     i am a developer by profession
# 4          4           5  i used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                nan
# 64457  64457       64867                                                nan
# 64458  64458       64898                                                nan
# 64459  64459       64925                                                nan
# 64460  64460       65112                                                nan
#
# ...

# %%
#updating row values
content.loc[1,['MAINBRANCH','AGE']] = ['hello',15]
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     I am a developer by profession
# 1          1           2                                              hello
# 2          2           3                        I code primarily as a hobby
# 3          3           4                     I am a developer by profession
# 4          4           5  I used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                NaN
# 64457  64457       64867                                                NaN
# 64458  64458       64898                                                NaN
# 64459  64459       64925                                                NaN
# 64460  64460       65112                                                NaN
#
# ...

# %%
#we can also use at in place of loc while updating(prepered)
content.at[2,'AGE']=20
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     I am a developer by profession
# 1          1           2                                              hello
# 2          2           3                        I code primarily as a hobby
# 3          3           4                     I am a developer by profession
# 4          4           5  I used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                NaN
# 64457  64457       64867                                                NaN
# 64458  64458       64898                                                NaN
# 64459  64459       64925                                                NaN
# 64460  64460       65112                                                NaN
#
# ...

# %% [markdown]
# filt = (content["AGE"]==25.0)
# content[filt]['MAINBRANCH']

# %% [markdown]
# # updating multiple row data

# %%
content['MAINBRANCH']=content['MAINBRANCH'].str.upper()

# %%
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     I AM A DEVELOPER BY PROFESSION
# 1          1           2                                              HELLO
# 2          2           3                        I CODE PRIMARILY AS A HOBBY
# 3          3           4                     I AM A DEVELOPER BY PROFESSION
# 4          4           5  I USED TO BE A DEVELOPER BY PROFESSION, BUT NO...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                NAN
# 64457  64457       64867                                                NAN
# 64458  64458       64898                                                NAN
# 64459  64459       64925                                                NAN
# 64460  64460       65112                                                NAN
#
# ...

# %% [markdown]
# # important function

# %%
#apply function
#content['HOBBYIST'].apply(len)
#content['HOBBYIST'] = [str(w) for w in content['HOBBYIST']]
#content['HOBBYIST'].apply(len)
#content['AGE'].astype(int).apply(min)
#content.max(axis=0)[0]
content.loc[content['AGE'].idxmax(skipna=True),'AGE']
#content[index=14375,'AGE']
# Out:
# 279.0

# %%
def update_hobbyist(hobbyist):
    return "Code as my hobby?"+str(hobbyist)
content['HOBBYIST'].apply(update_hobbyist)
# Out:
# 0        Code as my hobby?Yes
# 1         Code as my hobby?No
# 2        Code as my hobby?Yes
# 3        Code as my hobby?Yes
# 4        Code as my hobby?Yes
#                  ...
# 64456    Code as my hobby?Yes
# 64457    Code as my hobby?Yes
# 64458    Code as my hobby?Yes
# 64459    Code as my hobby?Yes
# 64460    Code as my hobby?Yes
# Name: HOBBYIST, Length: 64461, dtype: object

# %%
#content['HOBBYIST']=content['HOBBYIST'].apply(update_hobbyist)

# %%
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     I AM A DEVELOPER BY PROFESSION
# 1          1           2                                              HELLO
# 2          2           3                        I CODE PRIMARILY AS A HOBBY
# 3          3           4                     I AM A DEVELOPER BY PROFESSION
# 4          4           5  I USED TO BE A DEVELOPER BY PROFESSION, BUT NO...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                NaN
# 64457  64457       64867                                                NaN
# 64458  64458       64898                                                NaN
# 64459  64459       64925                                                NaN
# 64460  64460       65112                                                NaN
#
# ...

# %%
content['MAINBRANCH'] =content['MAINBRANCH'].apply(lambda x: (str(x)).lower())

# %%
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     i am a developer by profession
# 1          1           2                                              hello
# 2          2           3                        i code primarily as a hobby
# 3          3           4                     i am a developer by profession
# 4          4           5  i used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                nan
# 64457  64457       64867                                                nan
# 64458  64458       64898                                                nan
# 64459  64459       64925                                                nan
# 64460  64460       65112                                                nan
#
# ...

# %%
content.apply(len,axis='columns')
#content.apply(len)
# Out:
# 0        62
# 1        62
# 2        62
# 3        62
# 4        62
#          ..
# 64456    62
# 64457    62
# 64458    62
# 64459    62
# 64460    62
# Length: 64461, dtype: int64

# %%
len(content['MAINBRANCH'])
# Out:
# 64461

# %%
#content.apply(pd.Series.min)
#but this is not working and showing error
#TypeError: '<=' not supported between instances of 'str' and 'float'

# %%
content.apply(lambda x : x.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-b2998624ff3b> in <module>
# ----> 1 content.apply(lambda x : x.min())
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
#    7549     def applymap(self, func) -> "DataFrame":
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# ...

# %%
content.applymap(str.lower)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-e33cde8e41e5> in <module>
# ----> 1 content.applymap(str.lower)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in applymap(self, func)
#    7602             return lib.map_infer(x.astype(object)._values, func)
#    7603
# -> 7604         return self.apply(infer)
#    7605
#    7606     # ----------------------------------------------------------------------
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
#    7549     def applymap(self, func) -> "DataFrame":
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...

# %%
content.rename(columns={'CONVERTEDCOMP':'Salaryusd'})

# %% [markdown]
# # Adding rows and columns

# %%
#this is to handle the error occured in simple calculation
#below line is to handle the 'nan' it fills all those cells with 0
content = content.fillna(0)
#astype(datatype) is used to convert the values of a proper column adn pd..to_numeric is used to change the string value to integer 
content['AGER'] = content['AGE'].astype(int)+pd.to_numeric(content['AGE1STCODE'], errors='coerce')

# %%
content['AGER']
# Out:
# 0        13.0
# 1        34.0
# 2        35.0
# 3        43.0
# 4        47.0
#          ...
# 64456    16.0
# 64457     0.0
# 64458     0.0
# 64459     0.0
# 64460     0.0
# Name: AGER, Length: 64461, dtype: float64

# %%
#function to know the ttype of a column
content['AGER'].apply(type)

# %%
#this will delete the specific column and in place of just a column we could use a lsit of column
content.drop(columns = 'AGER')

# %%
#we can also split a column as well
content[[i for i in range(16)]]=content['MAINBRANCH'].str.split(' ',expand=True)
content
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 0          0           1                     i am a developer by profession
# 1          1           2                                              hello
# 2          2           3                        i code primarily as a hobby
# 3          3           4                     i am a developer by profession
# 4          4           5  i used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                nan
# 64457  64457       64867                                                nan
# 64458  64458       64898                                                nan
# 64459  64459       64925                                                nan
# 64460  64460       65112                                                nan
#
# ...

# %% [markdown]
# # adding a row or column

# %%
#this append method also takes a argument sort whose value could be True or False
content.append({'MAINBRANCH':'jai ho'},ignore_index=True)

# %%
#Dropping a row
filt = content[content['COUNTRY']=='Germany']
content.drop(filt.index)

# %% [markdown]
# # sorting the data

# %%
# we could also pass a list for ascending option like..content.sort_values(by=['MAINBRANCH','COUNTRY'])
content.sort_values(by='MAINBRANCH',ascending=False)

# %%
#if we want to sort dataframe using index we can use content.sort_index()
# wecan also sort a specific column in place of whole data base 
content['COUNTRY'].astype(str).sort_values(ascending=False).head(200)

# %%
content['CONVERTEDCOMP'].nlargest(50)

# %%
# we can also use nsmallest for smaalest 
content.nlargest(10,'CONVERTEDCOMP')

# %% [markdown]
# # groupping and aggreging

# %%
# lets say we want the average salary of python developer in germany
temp = (content['LANGUAGEWORKEDWITH'].str.contains('Python')) & (content['COUNTRY']=='Germany')
content.loc[temp,'CONVERTEDCOMP'].mean()

#this is the average salary of the python developers in germany
# Out:
# 52472.72021028037

# %%
#series.describe() is a good function
content.median()
# Out:
# INDEX            32230.0
# RESPONDENT       32231.0
# AGE                 25.0
# COMPTOTAL         2400.0
# CONVERTEDCOMP     6897.0
# WORKWEEKHRS         38.0
# AGER                40.0
# dtype: float64

# %%
#this function tells us the total no entries in that column
content['CONVERTEDCOMP'].count()
# Out:
# 64461

# %%
content['HOBBYIST'].value_counts()

# %%
#schema_df
#this 

content['SOACCOUNT'].value_counts(normalize=True)

# %%
content['SOACCOUNT'].value_counts(normalize=True)*100

# %% [markdown]
# # groupping

# %%
countries_grp = content.groupby('COUNTRY')
countries_grp.get_group('United States')
# Out:
#        INDEX  RESPONDENT                                         MAINBRANCH  \
# 4          4           5  i used to be a developer by profession, but no...
# 7          7           8                     i am a developer by profession
# 13        13          14                     i am a developer by profession
# 16        16          17                     i am a developer by profession
# 17        17          18                     i am a developer by profession
# ...      ...         ...                                                ...
# 64413  64413       58498                                                nan
# 64417  64417       58896                                                nan
# 64428  64428       60931                                                nan
# 64443  64443       63077                                                nan
# 64456  64456       64858                                                nan
#
# ...

# %%
#hahaha this is for countrywise salary and no of that salary aspirants
countries_grp['CONVERTEDCOMP'].value_counts()

# %%
# if we want the upper data for a specific country
countries_grp['CONVERTEDCOMP'].value_counts().loc['Afghanistan']

# %%
countries_grp['CONVERTEDCOMP'].mean().loc['Afghanistan']

# %%
countries_grp['CONVERTEDCOMP'].agg(['mean','median'])

# %%
# here we'll see how many people in germany use python
temp = (content['LANGUAGEWORKEDWITH'].str.contains('Python')) & (content['COUNTRY']=='Germany')
content.loc[temp,'LANGUAGEWORKEDWITH'].value_counts()
#filt = content['COUNTRY']=='India'
#content.loc[filt]['LANGUAGEWORKEDWITH'].str.contains('Python')

# %%
filt = content['COUNTRY']=='India'
content.loc[filt]['LANGUAGEWORKEDWITH'].str.contains('Python').sum()

# %%
filt = content['COUNTRY']=='India'
content.loc[filt]['LANGUAGEWORKEDWITH'].str.contains('Python')

# %%
countries_grp['LANGUAGEWORKEDWITH'].apply(lambda x:x.astype(str).str.contains('Python').sum())

# %% [markdown]
# # here we'll find the no of persons from each country who know python

# %%
country_respondents = content['COUNTRY'].value_counts()
country_respondents

# %%
country_uses_python = countries_grp['LANGUAGEWORKEDWITH'].apply(lambda x:x.astype(str).str.contains('Python').sum())
python_df = pd.concat('country_respondents','country_uses_python',axis='columns',ignore_index=True,sort=False)
country_uses_python

# %%
#this is above's solution
countries_grp['LANGUAGEWORKEDWITH'].apply(lambda x: x.astype(str).str.contains('Python').mean())*100
